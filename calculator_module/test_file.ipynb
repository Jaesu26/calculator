# %%
import calculator

# %%
help(calculator)
# Out:
# Help on module calculator:
#
# NAME
#     calculator
#
# DESCRIPTION
#     버전1 계산기입니다
#     네이버 계산기를 참고했습니다
#     4×5 크기로 구성했습니다
#
#     기능: 숫자입력, 등호, 사칙연산, 소괄호, 소수점, 입력창 초기화
#     기본적인 연산만 가능합니다
#     부족한 기능을 추가하여 버전2 계산기를 만들 예정입니다
#
# FUNCTIONS
#     clear_button_click()
#         ## entry clear
#
#     equal_button_click()
#         ## 등호 클릭
#
#     number_button_click(num)
#         ## 숫자 클릭
#
#     operation_button_click(op)
#         ## 사칙연산 클릭
#
#     paren_button_click(paren)
#         ## parentheses operation
#
#     plus_minus_button_click()
#         ## plus, minus sign
#
#     point_button_click()
#         ## decimal point
#
# DATA
#     b_0 = <tkinter.Button object .!frame2.!button18>
#     b_1 = <tkinter.Button object .!frame2.!button13>
#     b_2 = <tkinter.Button object .!frame2.!button14>
#     b_3 = <tkinter.Button object .!frame2.!button15>
#     b_4 = <tkinter.Button object .!frame2.!button9>
#     b_5 = <tkinter.Button object .!frame2.!button10>
# ...

# %%
import calculator2

# %%
help(calculator2)
# Out:
# Help on module calculator2:
#
# NAME
#     calculator2
#
# DESCRIPTION
#     버전2 계산기입니다
#     버전1 계산기에 부족한 기능을 추가했습니다
#     네이버 계산기를 참고했습니다
#     6×5 크기로 구성했습니다
#
#     새로운 기능: 제곱, 거듭제곤, 제곱근, 거듭제곱근, 상용로그, 자연로그, 팩토리얼(감마함수), Backspace, π, e
#
# FUNCTIONS
#     backspace_button_click()
#         ## Backspace
#
#     clear_button_click()
#         ## entry clear
#
#     equal_button_click()
#         ## 등호 클릭
#
#     number_button_click(num)
#         ## 숫자 클릭
#
#     operation_button_click(op)
#         ## 사칙연산 클릭
#
#     paren_button_click(paren)
#         ## other operation
#
#     plus_minus_button_click()
#         ## plus, minus sign
#
#     point_button_click()
#         ## decimal point
#
#     transcendental_number_button_click(tran_num)
#         ## Transcendental number(pi and e)
#
# DATA
#     b_0 = <tkinter.Button object .!frame2.!button18>
#     b_1 = <tkinter.Button object .!frame2.!button13>
#     b_2 = <tkinter.Button object .!frame2.!button14>
# ...
